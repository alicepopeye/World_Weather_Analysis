# %% [markdown]
# # 6.1.4 Create Latitude & Longtitude Combinations
# zip( , ) function
# * object in memory, par them and have the same index in an array into a tuple
# * you can only unzipped tuple once before it is removed from the computer's memory; make sure you add it to a list before moving on

# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather Map API Call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# print(url)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high = 90.000, size =1500)
lngs = np.random.uniform(low= -180.000, high =180.000, size =1500)

lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# # 6.1.5 Generate Random World Cities
# import citipy module

# %%
from citipy import citipy

# Create a list for holding the cities.
cities=[]

#Identify the nearest city for each latitude and longitude combiantion.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %% [markdown]
# # 6.2.6  Get the City Weather Data
# enumerate(),   for i, item in enumerate(list):
# try-except

# %%
# Declare an empty list to hold the weather data
city_data =[]

# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

# Create counterss for the record numbers 1-50 and the set counter
record_count =1
set_count =1

# Instead of using two for loops, we can use the enumerate() method as an alternative way 
# to iterate through the list of cities
# and retrieve both the index, and the city from the list.
# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | thayetmyo
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | yichang
# Processing Record 10 of Set 1 | sterling
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | venice
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | comodoro rivadavia
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | makakilo city
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | yulara
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | kavaratti
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | cardston
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | acajutla
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | kamyaran
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | kununurra
# Processing Record 39 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 1 | drayton valley
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | margate
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | adrar
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | ptuj
# Processing Record 49 of Set 1 | mehamn
# Processing Record 50 of Set 1 | sabzevar
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | vonitsa
# Processing Record 3 of Set 2 | douglas
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | arrecife
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | port lincoln
# Processing Record 12 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 2 | qaqortoq
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | veraval
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | teya
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | alofi
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | anloga
# Processing Record 25 of Set 2 | waipawa
# Processing Record 26 of Set 2 | monterey
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | fairbanks
# Processing Record 30 of Set 2 | njombe
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | viedma
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | narsaq
# Processing Record 37 of Set 2 | myaundzha
# Processing Record 38 of Set 2 | santa
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | tautira
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | kandrian
# Processing Record 44 of Set 2 | ust-kuyga
# Processing Record 45 of Set 2 | salalah
# Processing Record 46 of Set 2 | sao domingos
# Processing Record 47 of Set 2 | ilhabela
# Processing Record 48 of Set 2 | trinidad
# Processing Record 49 of Set 2 | parana
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | yatou
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | lata
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | geraldton
# Processing Record 7 of Set 3 | sobolevo
# Processing Record 8 of Set 3 | bayir
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | mahajanga
# Processing Record 11 of Set 3 | aswan
# Processing Record 12 of Set 3 | saint-augustin
# Processing Record 13 of Set 3 | alta floresta
# Processing Record 14 of Set 3 | kampot
# Processing Record 15 of Set 3 | batsfjord
# Processing Record 16 of Set 3 | leningradskiy
# Processing Record 17 of Set 3 | sawakin
# Processing Record 18 of Set 3 | taoudenni
# Processing Record 19 of Set 3 | westport
# Processing Record 20 of Set 3 | saiha
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | byron bay
# Processing Record 23 of Set 3 | ixtapa
# Processing Record 24 of Set 3 | carutapera
# Processing Record 25 of Set 3 | yabelo
# Processing Record 26 of Set 3 | naze
# Processing Record 27 of Set 3 | martapura
# Processing Record 28 of Set 3 | tripoli
# Processing Record 29 of Set 3 | katsuura
# Processing Record 30 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 3 | moose factory
# Processing Record 33 of Set 3 | newport
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | ayan
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | moldava nad bodvou
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | kamaishi
# Processing Record 42 of Set 3 | mackenzie
# Processing Record 43 of Set 3 | fortuna
# Processing Record 44 of Set 3 | biak
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | tsogni
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | ambon
# Processing Record 49 of Set 3 | vargashi
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | steamboat springs
# Processing Record 2 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 4 | vanimo
# Processing Record 4 of Set 4 | katobu
# Processing Record 5 of Set 4 | tazovskiy
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | russell
# Processing Record 8 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 9 of Set 4 | port moresby
# Processing Record 10 of Set 4 | treinta y tres
# Processing Record 11 of Set 4 | goderich
# Processing Record 12 of Set 4 | parabel
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | ati
# Processing Record 16 of Set 4 | sao jose da coroa grande
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | butterworth
# Processing Record 19 of Set 4 | punta cardon
# Processing Record 20 of Set 4 | cockburn town
# Processing Record 21 of Set 4 | scalea
# Processing Record 22 of Set 4 | roald
# Processing Record 23 of Set 4 | isangel
# Processing Record 24 of Set 4 | tilichiki
# Processing Record 25 of Set 4 | kasamwa
# Processing Record 26 of Set 4 | dzaoudzi
# Processing Record 27 of Set 4 | hambantota
# Processing Record 28 of Set 4 | kirakira
# Processing Record 29 of Set 4 | ponta delgada
# Processing Record 30 of Set 4 | constitucion
# Processing Record 31 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 4 | kabo
# Processing Record 33 of Set 4 | ampanihy
# Processing Record 34 of Set 4 | sambava
# Processing Record 35 of Set 4 | kota tinggi
# Processing Record 36 of Set 4 | nioro
# Processing Record 37 of Set 4 | quatre cocos
# Processing Record 38 of Set 4 | tezu
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | fort nelson
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | bestobe
# Processing Record 43 of Set 4 | mount isa
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | corpus christi
# Processing Record 47 of Set 4 | nsanje
# Processing Record 48 of Set 4 | meulaboh
# Processing Record 49 of Set 4 | puerto colombia
# Processing Record 50 of Set 4 | saint anthony
# Processing Record 1 of Set 5 | bairiki
# Processing Record 2 of Set 5 | bilibino
# Processing Record 3 of Set 5 | dhidhdhoo
# Processing Record 4 of Set 5 | trelew
# Processing Record 5 of Set 5 | kompaniyivka
# Processing Record 6 of Set 5 | yumen
# Processing Record 7 of Set 5 | ornskoldsvik
# Processing Record 8 of Set 5 | honningsvag
# Processing Record 9 of Set 5 | athabasca
# Processing Record 10 of Set 5 | avera
# Processing Record 11 of Set 5 | lingao
# Processing Record 12 of Set 5 | daru
# Processing Record 13 of Set 5 | hirado
# Processing Record 14 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 5 | tambacounda
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | paragominas
# Processing Record 18 of Set 5 | asfi
# Processing Record 19 of Set 5 | ust-tarka
# Processing Record 20 of Set 5 | ostrovnoy
# Processing Record 21 of Set 5 | seoul
# Processing Record 22 of Set 5 | pingxiang
# Processing Record 23 of Set 5 | aasiaat
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | oktyabrskoye
# Processing Record 26 of Set 5 | kokkola
# Processing Record 27 of Set 5 | maldonado
# Processing Record 28 of Set 5 | rocha
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | grindavik
# Processing Record 31 of Set 5 | srednekolymsk
# Processing Record 32 of Set 5 | la peca
# Processing Record 33 of Set 5 | dikson
# Processing Record 34 of Set 5 | karasburg
# Processing Record 35 of Set 5 | qiongshan
# Processing Record 36 of Set 5 | talcahuano
# Processing Record 37 of Set 5 | hamilton
# Processing Record 38 of Set 5 | pizarro
# Processing Record 39 of Set 5 | soe
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | chapais
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | waddan
# Processing Record 44 of Set 5 | kaeo
# Processing Record 45 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 5 | faanui
# Processing Record 47 of Set 5 | wanaka
# Processing Record 48 of Set 5 | faya
# Processing Record 49 of Set 5 | souillac
# Processing Record 50 of Set 5 | bud
# Processing Record 1 of Set 6 | primorskiy
# Processing Record 2 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 6 | lagoa
# Processing Record 4 of Set 6 | makhu
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | vangaindrano
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | narasannapeta
# Processing Record 9 of Set 6 | marawi
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | cherskiy
# Processing Record 12 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 6 | marquette
# Processing Record 14 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 6 | sao filipe
# Processing Record 16 of Set 6 | san quintin
# Processing Record 17 of Set 6 | andilamena
# Processing Record 18 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 6 | tura
# Processing Record 20 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 6 | saldanha
# Processing Record 22 of Set 6 | sola
# Processing Record 23 of Set 6 | talnakh
# Processing Record 24 of Set 6 | aksha
# Processing Record 25 of Set 6 | maragogi
# Processing Record 26 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 6 | simav
# Processing Record 28 of Set 6 | batagay-alyta
# Processing Record 29 of Set 6 | xinqing
# Processing Record 30 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 6 | twin falls
# Processing Record 32 of Set 6 | ukiah
# Processing Record 33 of Set 6 | oromocto
# Processing Record 34 of Set 6 | cozumel
# Processing Record 35 of Set 6 | tuatapere
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | havelock
# Processing Record 38 of Set 6 | andenes
# Processing Record 39 of Set 6 | lavrentiya
# Processing Record 40 of Set 6 | luderitz
# Processing Record 41 of Set 6 | krutinka
# Processing Record 42 of Set 6 | berlevag
# Processing Record 43 of Set 6 | los andes
# Processing Record 44 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 6 | alice
# Processing Record 46 of Set 6 | oranjemund
# Processing Record 47 of Set 6 | boulder city
# Processing Record 48 of Set 6 | wencheng
# Processing Record 49 of Set 6 | kobayashi
# Processing Record 50 of Set 6 | new glasgow
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | qafsah
# City not found. Skipping...
# Processing Record 3 of Set 7 | ridgecrest
# Processing Record 4 of Set 7 | capaci
# Processing Record 5 of Set 7 | hornepayne
# Processing Record 6 of Set 7 | inyonga
# Processing Record 7 of Set 7 | romny
# Processing Record 8 of Set 7 | katherine
# Processing Record 9 of Set 7 | kaffrine
# Processing Record 10 of Set 7 | ushtobe
# Processing Record 11 of Set 7 | hearst
# Processing Record 12 of Set 7 | iqaluit
# Processing Record 13 of Set 7 | puksoozero
# Processing Record 14 of Set 7 | oriximina
# Processing Record 15 of Set 7 | yarada
# Processing Record 16 of Set 7 | deloraine
# Processing Record 17 of Set 7 | lethem
# Processing Record 18 of Set 7 | virginia
# Processing Record 19 of Set 7 | santa maria
# Processing Record 20 of Set 7 | genhe
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | aksu
# Processing Record 23 of Set 7 | kishtwar
# Processing Record 24 of Set 7 | saint-philippe
# Processing Record 25 of Set 7 | colares
# Processing Record 26 of Set 7 | ajaccio
# Processing Record 27 of Set 7 | kawalu
# Processing Record 28 of Set 7 | vanavara
# Processing Record 29 of Set 7 | kloulklubed
# Processing Record 30 of Set 7 | luanda
# Processing Record 31 of Set 7 | fernley
# Processing Record 32 of Set 7 | buchanan
# Processing Record 33 of Set 7 | beloha
# Processing Record 34 of Set 7 | pasni
# Processing Record 35 of Set 7 | zilupe
# Processing Record 36 of Set 7 | belyy yar
# Processing Record 37 of Set 7 | ugep
# Processing Record 38 of Set 7 | sitka
# Processing Record 39 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 40 of Set 7 | yar-sale
# Processing Record 41 of Set 7 | selikhino
# Processing Record 42 of Set 7 | cururupu
# Processing Record 43 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 7 | bafq
# Processing Record 45 of Set 7 | bulls
# Processing Record 46 of Set 7 | brightwater
# Processing Record 47 of Set 7 | tucupita
# Processing Record 48 of Set 7 | nanakuli
# Processing Record 49 of Set 7 | presidencia roque saenz pena
# Processing Record 50 of Set 7 | yangambi
# Processing Record 1 of Set 8 | saint-joseph
# Processing Record 2 of Set 8 | puerto varas
# Processing Record 3 of Set 8 | evenskjaer
# City not found. Skipping...
# Processing Record 4 of Set 8 | banjar
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 8 | terrace
# Processing Record 7 of Set 8 | otane
# Processing Record 8 of Set 8 | sayhat
# Processing Record 9 of Set 8 | la palma
# Processing Record 10 of Set 8 | zyryanka
# Processing Record 11 of Set 8 | bodaybo
# Processing Record 12 of Set 8 | kyra
# Processing Record 13 of Set 8 | sur
# Processing Record 14 of Set 8 | vytegra
# Processing Record 15 of Set 8 | ankang
# Processing Record 16 of Set 8 | torbat-e jam
# Processing Record 17 of Set 8 | baherden
# Processing Record 18 of Set 8 | wuning
# Processing Record 19 of Set 8 | sinnamary
# Processing Record 20 of Set 8 | zitiste
# Processing Record 21 of Set 8 | guayaramerin
# Processing Record 22 of Set 8 | corinto
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | mnogovershinnyy
# Processing Record 25 of Set 8 | madimba
# Processing Record 26 of Set 8 | buala
# Processing Record 27 of Set 8 | ayagoz
# Processing Record 28 of Set 8 | neepawa
# Processing Record 29 of Set 8 | bambous virieux
# Processing Record 30 of Set 8 | pangai
# Processing Record 31 of Set 8 | camacha
# Processing Record 32 of Set 8 | narrabri
# Processing Record 33 of Set 8 | shakawe
# Processing Record 34 of Set 8 | bejar
# Processing Record 35 of Set 8 | ossora
# Processing Record 36 of Set 8 | khatanga
# Processing Record 37 of Set 8 | naryan-mar
# Processing Record 38 of Set 8 | havoysund
# Processing Record 39 of Set 8 | luleburgaz
# Processing Record 40 of Set 8 | cabedelo
# Processing Record 41 of Set 8 | tabou
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | indramayu
# Processing Record 44 of Set 8 | rafai
# Processing Record 45 of Set 8 | vestmannaeyjar
# Processing Record 46 of Set 8 | kluang
# Processing Record 47 of Set 8 | shimoda
# Processing Record 48 of Set 8 | turukhansk
# Processing Record 49 of Set 8 | vannes
# Processing Record 50 of Set 8 | cayenne
# Processing Record 1 of Set 9 | fougamou
# Processing Record 2 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 9 | beringovskiy
# Processing Record 4 of Set 9 | banda aceh
# Processing Record 5 of Set 9 | ucluelet
# Processing Record 6 of Set 9 | bubaque
# Processing Record 7 of Set 9 | redea
# Processing Record 8 of Set 9 | kaitangata
# Processing Record 9 of Set 9 | vila
# Processing Record 10 of Set 9 | chara
# Processing Record 11 of Set 9 | kidal
# Processing Record 12 of Set 9 | suntar
# Processing Record 13 of Set 9 | waingapu
# Processing Record 14 of Set 9 | san jose
# Processing Record 15 of Set 9 | ballina
# Processing Record 16 of Set 9 | olafsvik
# Processing Record 17 of Set 9 | chester
# Processing Record 18 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 9 | vila franca do campo
# Processing Record 20 of Set 9 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 21 of Set 9 | fare
# Processing Record 22 of Set 9 | hervey bay
# Processing Record 23 of Set 9 | zhucheng
# Processing Record 24 of Set 9 | touros
# Processing Record 25 of Set 9 | buta
# Processing Record 26 of Set 9 | batemans bay
# Processing Record 27 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 9 | ipil
# Processing Record 29 of Set 9 | gat
# Processing Record 30 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 9 | te anau
# Processing Record 32 of Set 9 | neryungri
# Processing Record 33 of Set 9 | aksarka
# Processing Record 34 of Set 9 | vostok
# Processing Record 35 of Set 9 | oistins
# Processing Record 36 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 9 | ban nahin
# Processing Record 38 of Set 9 | sabang
# Processing Record 39 of Set 9 | katangli
# Processing Record 40 of Set 9 | axim
# Processing Record 41 of Set 9 | flora
# Processing Record 42 of Set 9 | nizwa
# Processing Record 43 of Set 9 | inverell
# Processing Record 44 of Set 9 | igarka
# Processing Record 45 of Set 9 | san ramon
# Processing Record 46 of Set 9 | bin qirdan
# Processing Record 47 of Set 9 | turbat
# Processing Record 48 of Set 9 | cogua
# Processing Record 49 of Set 9 | paka
# Processing Record 50 of Set 9 | sharjah
# Processing Record 1 of Set 10 | whitehorse
# Processing Record 2 of Set 10 | saskylakh
# Processing Record 3 of Set 10 | madison
# Processing Record 4 of Set 10 | abu dhabi
# Processing Record 5 of Set 10 | sandakan
# Processing Record 6 of Set 10 | bukoba
# Processing Record 7 of Set 10 | gornopravdinsk
# Processing Record 8 of Set 10 | coihaique
# Processing Record 9 of Set 10 | buraydah
# Processing Record 10 of Set 10 | bagalkot
# Processing Record 11 of Set 10 | rovaniemi
# Processing Record 12 of Set 10 | gazli
# Processing Record 13 of Set 10 | shaartuz
# City not found. Skipping...
# Processing Record 14 of Set 10 | araouane
# Processing Record 15 of Set 10 | ternate
# Processing Record 16 of Set 10 | vestmanna
# Processing Record 17 of Set 10 | lokosovo
# Processing Record 18 of Set 10 | montepuez
# Processing Record 19 of Set 10 | aranda de duero
# Processing Record 20 of Set 10 | port augusta
# Processing Record 21 of Set 10 | port hardy
# Processing Record 22 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 10 | durban
# Processing Record 24 of Set 10 | mananjary
# Processing Record 25 of Set 10 | mwinilunga
# Processing Record 26 of Set 10 | severodvinsk
# Processing Record 27 of Set 10 | damghan
# Processing Record 28 of Set 10 | wasilla
# Processing Record 29 of Set 10 | gembloux
# Processing Record 30 of Set 10 | puerto carreno
# Processing Record 31 of Set 10 | saint-georges
# Processing Record 32 of Set 10 | chicama
# Processing Record 33 of Set 10 | mwandiga
# Processing Record 34 of Set 10 | mashivka
# Processing Record 35 of Set 10 | ilinskiy
# Processing Record 36 of Set 10 | herat
# Processing Record 37 of Set 10 | guadalupe y calvo
# Processing Record 38 of Set 10 | tabatinga
# Processing Record 39 of Set 10 | svetlogorsk
# Processing Record 40 of Set 10 | kaeng khlo
# City not found. Skipping...
# Processing Record 41 of Set 10 | pato branco
# Processing Record 42 of Set 10 | puerto cabello
# Processing Record 43 of Set 10 | pangoa
# Processing Record 44 of Set 10 | amontada
# Processing Record 45 of Set 10 | tual
# Processing Record 46 of Set 10 | puerto madryn
# Processing Record 47 of Set 10 | lisakovsk
# Processing Record 48 of Set 10 | beroroha
# Processing Record 49 of Set 10 | ahipara
# Processing Record 50 of Set 10 | krasnokamensk
# Processing Record 1 of Set 11 | port macquarie
# Processing Record 2 of Set 11 | dalsingh sarai
# Processing Record 3 of Set 11 | kenora
# Processing Record 4 of Set 11 | havre-saint-pierre
# Processing Record 5 of Set 11 | kozhva
# Processing Record 6 of Set 11 | vila velha
# Processing Record 7 of Set 11 | redlands
# Processing Record 8 of Set 11 | tabuk
# Processing Record 9 of Set 11 | ambatondrazaka
# Processing Record 10 of Set 11 | codrington
# Processing Record 11 of Set 11 | le port
# Processing Record 12 of Set 11 | luwuk
# Processing Record 13 of Set 11 | ouadda
# Processing Record 14 of Set 11 | shingu
# Processing Record 15 of Set 11 | linhares
# Processing Record 16 of Set 11 | samarai
# Processing Record 17 of Set 11 | borogontsy
# Processing Record 18 of Set 11 | xingyi
# Processing Record 19 of Set 11 | ketchikan
# Processing Record 20 of Set 11 | mantua
# Processing Record 21 of Set 11 | yelizovo
# Processing Record 22 of Set 11 | lichinga
# Processing Record 23 of Set 11 | poggibonsi
# Processing Record 24 of Set 11 | izhma
# Processing Record 25 of Set 11 | tiarei
# Processing Record 26 of Set 11 | kenai
# Processing Record 27 of Set 11 | san andres
# Processing Record 28 of Set 11 | halifax
# Processing Record 29 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 11 | muisne
# Processing Record 31 of Set 11 | skibbereen
# Processing Record 32 of Set 11 | tupelo
# Processing Record 33 of Set 11 | muzhi
# Processing Record 34 of Set 11 | jutai
# Processing Record 35 of Set 11 | ulladulla
# Processing Record 36 of Set 11 | jacareacanga
# Processing Record 37 of Set 11 | talara
# Processing Record 38 of Set 11 | martinopolis
# Processing Record 39 of Set 11 | lazaro cardenas
# Processing Record 40 of Set 11 | itoman
# Processing Record 41 of Set 11 | pochutla
# Processing Record 42 of Set 11 | maxixe
# Processing Record 43 of Set 11 | krasnyy chikoy
# Processing Record 44 of Set 11 | rio verde de mato grosso
# Processing Record 45 of Set 11 | lozovo
# Processing Record 46 of Set 11 | hargeysa
# Processing Record 47 of Set 11 | eirunepe
# Processing Record 48 of Set 11 | san rafael
# Processing Record 49 of Set 11 | champerico
# Processing Record 50 of Set 11 | yenagoa
# Processing Record 1 of Set 12 | ashland
# Processing Record 2 of Set 12 | aitape
# Processing Record 3 of Set 12 | damietta
# Processing Record 4 of Set 12 | skibotn
# Processing Record 5 of Set 12 | pekan
# Processing Record 6 of Set 12 | eureka
# Processing Record 7 of Set 12 | egvekinot
# Processing Record 8 of Set 12 | chitungwiza
# Processing Record 9 of Set 12 | vengerovo
# Processing Record 10 of Set 12 | mendeleyevsk
# Processing Record 11 of Set 12 | campbellsville
# Processing Record 12 of Set 12 | erzin
# Processing Record 13 of Set 12 | matara
# Processing Record 14 of Set 12 | pattaya
# Processing Record 15 of Set 12 | sorong
# Processing Record 16 of Set 12 | mount gambier
# Processing Record 17 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 12 | kamra
# Processing Record 19 of Set 12 | casablanca
# Processing Record 20 of Set 12 | huesca
# Processing Record 21 of Set 12 | warkworth
# Processing Record 22 of Set 12 | hvolsvollur
# Processing Record 23 of Set 12 | aykhal
# Processing Record 24 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 12 | mandapam
# Processing Record 26 of Set 12 | cotonou
# Processing Record 27 of Set 12 | hami
# Processing Record 28 of Set 12 | lobito
# Processing Record 29 of Set 12 | barbalha
# Processing Record 30 of Set 12 | agadir
# Processing Record 31 of Set 12 | new philadelphia
# Processing Record 32 of Set 12 | liwale
# Processing Record 33 of Set 12 | bilma
# Processing Record 34 of Set 12 | noumea
# Processing Record 35 of Set 12 | nizhniy tsasuchey
# Processing Record 36 of Set 12 | uvat
# Processing Record 37 of Set 12 | masty
# Processing Record 38 of Set 12 | albanel
# Processing Record 39 of Set 12 | emba
# Processing Record 40 of Set 12 | nevsehir
# Processing Record 41 of Set 12 | longhua
# Processing Record 42 of Set 12 | zhezkazgan
# Processing Record 43 of Set 12 | mamit
# Processing Record 44 of Set 12 | shishou
# Processing Record 45 of Set 12 | mamakan
# Processing Record 46 of Set 12 | chudniv
# Processing Record 47 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 12 | coahuayana
# Processing Record 49 of Set 12 | kemijarvi
# Processing Record 50 of Set 12 | teguise
# Processing Record 1 of Set 13 | makung
# City not found. Skipping...
# Processing Record 2 of Set 13 | dovolnoye
# Processing Record 3 of Set 13 | krasnogorskoye
# Processing Record 4 of Set 13 | khandbari
# Processing Record 5 of Set 13 | moncton
# Processing Record 6 of Set 13 | leua
# Processing Record 7 of Set 13 | kudahuvadhoo
# Processing Record 8 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 9 of Set 13 | farmington
# Processing Record 10 of Set 13 | morant bay
# Processing Record 11 of Set 13 | plettenberg bay
# Processing Record 12 of Set 13 | kouango
# Processing Record 13 of Set 13 | bereda
# Processing Record 14 of Set 13 | altay
# Processing Record 15 of Set 13 | coolum beach
# Processing Record 16 of Set 13 | la ronge
# Processing Record 17 of Set 13 | podor
# Processing Record 18 of Set 13 | aguimes
# Processing Record 19 of Set 13 | kant
# Processing Record 20 of Set 13 | outjo
# Processing Record 21 of Set 13 | baykit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 572

# %% [markdown]
# # 6.2.7 Create a DataFrame of City Weather Data

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     53.60        62          40        6.91
# 1    Busselton -33.6500  115.3333     60.01        85         100       10.25
# 2      Mataura -46.1927  168.8643     64.00        69          67        5.01
# 3    Thayetmyo  19.3167   95.1833     83.61        56           0        8.37
# 4  New Norfolk -42.7826  147.0587     64.00        71         100        1.99
# 5    Carnarvon -24.8667  113.6333     77.00        64           0       19.01
# 6        Bluff -46.6000  168.3333     64.00        69          65        5.01
# 7      Yichang  30.7144  111.2847     63.18        69          11        2.39
# 8     Sterling  39.0062  -77.4286     55.99        62          90        3.44
# 9  Yellowknife  62.4560 -114.3525     41.00        48          20       10.36
#
#   Country                 Date
# 0      AR  2021-04-19 01:03:32
# 1      AU  2021-04-19 01:02:11
# 2      NZ  2021-04-19 01:07:08
# 3      MM  2021-04-19 01:07:09
# 4      AU  2021-04-19 01:07:09
# 5      AU  2021-04-19 01:07:10
# 6      NZ  2021-04-19 01:04:58
# 7      CN  2021-04-19 01:07:10
# 8      US  2021-04-19 01:07:11
# 9      CA  2021-04-19 01:07:11

# %%
# Reorder the column
new_column_order =["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df=city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0      Ushuaia      AR  2021-04-19 01:03:32 -54.8000  -68.3000     53.60
# 1    Busselton      AU  2021-04-19 01:02:11 -33.6500  115.3333     60.01
# 2      Mataura      NZ  2021-04-19 01:07:08 -46.1927  168.8643     64.00
# 3    Thayetmyo      MM  2021-04-19 01:07:09  19.3167   95.1833     83.61
# 4  New Norfolk      AU  2021-04-19 01:07:09 -42.7826  147.0587     64.00
# 5    Carnarvon      AU  2021-04-19 01:07:10 -24.8667  113.6333     77.00
# 6        Bluff      NZ  2021-04-19 01:04:58 -46.6000  168.3333     64.00
# 7      Yichang      CN  2021-04-19 01:07:10  30.7144  111.2847     63.18
# 8     Sterling      US  2021-04-19 01:07:11  39.0062  -77.4286     55.99
# 9  Yellowknife      CA  2021-04-19 01:07:11  62.4560 -114.3525     41.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        62          40        6.91
# 1        85         100       10.25
# 2        69          67        5.01
# 3        56           0        8.37
# 4        71         100        1.99
# 5        64           0       19.01
# 6        69          65        5.01
# 7        69          11        2.39
# 8        62          90        3.44
# 9        48          20       10.36

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# # 6.3.1 Plot Latitude vs Temperature

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %% [markdown]
# time module
# time.time()  = get today's date in second since 1/1/1970
# time.strftime("%x") = get today's date

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %% [markdown]
# # 6.3.2 Plot Latitude vs Humidity

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %% [markdown]
# # 6.3.3 Plot Latitude vs Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %% [markdown]
# # 6.3.4 Latitude vs Cloudiness

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %% [markdown]
# # 6.4.2 Find the Correlation bewteen Latitude and Maximum Temperature

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
   
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=10, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %% [markdown]
# Create the Hemisphere DataFrames
# The loc method accesses a group of rows and columns in the current DataFrame by an index, labels, or a Boolean array.
# row = df.loc[row_index]

# %%
index13=city_data_df.loc[13]
index13
# Out:
# City                         Hilo
# Country                        US
# Date          2021-04-19 01:07:13
# Lat                       19.7297
# Lng                       -155.09
# Max Temp                     80.6
# Humidity                       57
# Cloudiness                     40
# Wind Speed                   11.5
# Name: 13, dtype: object

# %%
# to get all Northern Hemisphere latitudes, for latitudes greater than or equal to 0
city_data_df["Lat"]>=0
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 567     True
# 568     True
# 569     True
# 570    False
# 571     True
# Name: Lat, Length: 572, dtype: bool

# %%
#  to return a DataFrame with all data fitting the criteria, for latitudes greater than or equal to 0,
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 3      Thayetmyo      MM  2021-04-19 01:07:09  19.3167   95.1833     83.61
# 7        Yichang      CN  2021-04-19 01:07:10  30.7144  111.2847     63.18
# 8       Sterling      US  2021-04-19 01:07:11  39.0062  -77.4286     55.99
# 9    Yellowknife      CA  2021-04-19 01:07:11  62.4560 -114.3525     41.00
# 10  Norman Wells      CA  2021-04-19 01:07:11  65.2820 -126.8329     46.40
#
#     Humidity  Cloudiness  Wind Speed
# 3         56           0        8.37
# 7         69          11        2.39
# 8         62          90        3.44
# 9         48          20       10.36
# 10        46           1        9.22

# %%
# Now assign this DataFrame to the variable northern_hemi_df to access the data to perform linear regression
# To create DataFrames for the Northern and Southern Hemispheres' data

# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Perform Linear Regression on the Maximum Temperature for the Northern Hemisphere

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\nfor Maximum Temperature', 'Max Temp',(20,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\nfor Maximum Temperature', 'Max Temp',(-50,80))

# %% [markdown]
# # 6.4.3 Find the Correlation between Latitude and Percent Humidity

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\nfor % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\nfor % Humidity', '% Humidity',(-50,40))

# %% [markdown]
# # 6.4.4 Find the Correlation between Latitude and Percent Cloudiness

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\nfor % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\nfor % Cloudiness', '% Cloudiness',(-50,60))

# %% [markdown]
# # 6.45 Find the Correlation between Latitude and Wind Speed

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\nfor Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\nfor Wind Speed', 'Wind Speed',(-50,35))
